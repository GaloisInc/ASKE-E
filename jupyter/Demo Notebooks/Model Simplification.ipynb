# %%
ras = loadPNC("emmaa_rasmachine.json")

# %%
describeModel(ras)
# Out:
# |Name|State/Param|Data Type|Value|
# |---|---|---|---|
# |J:AKT1(Y474='p', T308='p', S473='p', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='p', T308='p', S473='u', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='p', T308='u', S473='p', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='p', T308='u', S473='u', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='u', T308='p', S473='p', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='u', T308='p', S473='u', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# |J:AKT1(Y474='u', T308='u', S473='p', S475='u', T450='u', Y315='u', Y326='u', K276='n', kinase='inactive')_init|input|Integer|--|
# ...

# %%
ras_simpl = simplify(ras, ["J:TYMS()"])

# %%
describeModel(ras_simpl)
# Out:
# |Name|State/Param|Data Type|Value|
# |---|---|---|---|
