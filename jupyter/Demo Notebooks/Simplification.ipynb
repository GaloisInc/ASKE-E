# %%
define abc
    0.4, A --> B
    0.3, A --> C
    0.6, D --> E
    0.4, E --> B
    0.2, F --> A
    0.7, G --> C
    0.8, H --> G
    0.9, H --> D
end

# %%
modelGraph(abc)

# %%
modelGraph(simplify(abc, ["A"]))

# %%
define seirp
       0.4, S --> E
       0.3, S --> Ip
       0.25, S --> Hp
       0.6, E --> I
       0.4, E --> H
       0.5, I --> R
       0.6, H --> R
       0.3, Ip --> R
       0.5, Hp --> R
end

# %%
modelGraph(seirp)

# %%
modelGraph(simplify(seirp, ["H"]))

# %%
define syrup
       0.4, Spdx --> Epdx
       0.3, Spdx --> Ippdx
       0.25, Spdx --> Hppdx
       0.6, Epdx --> Ipdx
       0.4, Epdx --> Hpdx
       0.5, Ipdx --> Rpdx
       0.6, Hpdx --> Rpdx
       0.3, Ippdx --> Rppdx
       0.5, Hppdx --> Rppdx
       0.4, Ssal --> Esal
       0.3, Ssal --> Ipsal
       0.25, Ssal --> Hpsal
       0.6, Esal --> Isal
       0.4, Esal --> Hsal
       0.5, Isal --> Rsal
       0.6, Hsal --> Rsal
       0.3, Ipsal --> Rpsal
       0.5, Hpsal --> Rpsal
       0.2, Ssal --> Spdx
       0.2, Spdx --> Ssal
       0.2, Isal --> Ipdx
       0.2, Ipdx --> Isal
       0.2, Esal --> Epdx
       0.2, Epdx --> Esal
       0.2, Ipsal --> Ippdx
       0.2, Ippdx --> Ipsal
end

# %%
modelGraph(syrup)

# %%
modelGraph(simplify(syrup, ["Hpdx"]))
