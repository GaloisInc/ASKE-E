# %% [markdown]
# # Model Skill Reporting

# %% [markdown]
# ## Simulate ground truth data

# %%
data = loadCSV("sirs-simulated.csv")
times = data.time
infected_ground_truth = value(data.I)

# %% [markdown]
# ## Load and simulate models of interest

# %%
nSamples = 200
model1 = loadESL("sir.easel")
model2 = loadESL("sir-vd.easel")
model3 = loadESL("sirs.easel")

# %%
model1_samples = value(sample(model1.I at times, nSamples))
model2_samples = value(sample(model2.I at times, nSamples))
model3_samples = value(sample(model3.I at times, nSamples))

# %% [markdown]
# ## Compute ranking

# %%
alphas = [0.02, 0.05, 0.1, 0.2, 0.4, 0.8]
ranks = modelSkillRank([model1_samples, model2_samples, model3_samples], 
                        alphas, 
                        infected_ground_truth)

table(["model", "mean score"], [["model1", "model2", "model3"], ranks])
# Out:
# |model|mean score|
# |---|---|
# |model1|0.3|
# |model2|0.4|
# |model3|0.8|

# %% [markdown]
# ## Plot models vs. ground truth

# %%
m1 = series(mean(model1_samples), "Model 1", {{style="line"}})
m2 = series(mean(model2_samples), "Model 2", {{style="line"}})
m3 = series(mean(model3_samples), "Model 3", {{style="line"}})
ground_truth = series(infected_ground_truth, "Truth", {{style="squares"}})

# %%
plot("Models vs. Actual", 
     [m1, m2, m3, ground_truth],
     times,
     "T")

# %% [markdown]
# ## Distribution of Model Predictions

# %%
histogram(sample(model1.I at max(data.time) + 7, 100), 20)
histogram(sample(model2.I at max(data.time) + 7, 100), 20)
histogram(sample(model3.I at max(data.time) + 7, 100), 20)
# Out:
# [{"lo": 8.0, "hi": 9.0, "count": 6}, {"lo": 19.0, "hi": 20.0, "count": 3}, {"lo": 13.0, "hi": 14.0, "count": 10}, {"lo": 16.0, "hi": 17.0, "count": 7}, {"lo": 7.0, "hi": 8.0, "count": 5}, {"lo": 12.0, "hi": 13.0, "count": 14}, {"lo": 23.0, "hi": 24.0, "count": 1}, {"lo": 6.0, "hi": 7.0, "count": 3}, {"lo": 17.0, "hi": 18.0, "count": 3}, {"lo": 20.0, "hi": 21.0, "count": 2}, {"lo": 11.0, "hi": 12.0, "count": 12}, {"lo": 14.0, "hi": 15.0, "count": 9}, {"lo": 10.0, "hi": 11.0, "count": 3}, {"lo": 15.0, "hi": 16.0, "count": 9}, {"lo": 4.0, "hi": 5.0, "count": 1}, {"lo": 18.0, "hi": 19.0, "count": 4}, {"lo": 9.0, "hi": 10.0, "count": 8}]
# [{"lo": 18.8, "hi": 20.75, "count": 6}, {"lo": 40.25, "hi": 42.2, "count": 1}, {"lo": 28.55, "hi": 30.5, "count": 18}, {"lo": 34.4, "hi": 36.349999999999994, "count": 8}, {"lo": 26.6, "hi": 28.55, "count": 6}, {"lo": 48.05, "hi": 50.0, "count": 1}, {"lo": 36.349999999999994, "hi": 38.3, "count": 5}, {"lo": 42.2, "hi": 44.15, "count": 3}, {"lo": 24.65, "hi": 26.6, "count": 11}, {"lo": 12.95, "hi": 14.9, "count": 1}, {"lo": 30.5, "hi": 32.45, "count": 11}, {"lo": 22.7, "hi": 24.65, "count": 10}, {"lo": 32.45, "hi": 34.4, "count": 9}, {"lo": 11.0, "hi": 12.95, "count": 1}, {"lo": 38.3, "hi": 40.25, "count": 4}, {"lo": 20.75, "hi": 22.7, "count": 5}]
# [{"lo": 238.8, "hi": 242.75, "count": 1}, {"lo": 282.25, "hi": 286.2, "count": 7}, {"lo": 258.55, "hi": 262.5, "count": 8}, {"lo": 294.1, "hi": 298.05, "count": 1}, {"lo": 270.4, "hi": 274.35, "count": 8}, {"lo": 234.85, "hi": 238.8, "count": 1}, {"lo": 254.6, "hi": 258.55, "count": 7}, {"lo": 298.05, "hi": 302.0, "count": 1}, {"lo": 230.9, "hi": 234.85, "count": 1}, {"lo": 274.35, "hi": 278.3, "count": 5}, {"lo": 286.2, "hi": 290.15, "count": 8}, {"lo": 250.65, "hi": 254.6, "count": 9}, {"lo": 262.5, "hi": 266.45, "count": 6}, {"lo": 246.7, "hi": 250.65, "count": 8}, {"lo": 290.15, "hi": 294.1, "count": 2}, {"lo": 266.45, "hi": 270.4, "count": 14}, {"lo": 223.0, "hi": 226.95, "count": 1}, {"lo": 278.3, "hi": 282.25, "count": 6}, {"lo": 242.75, "hi": 246.7, "count": 6}]
