# %% [markdown]
# # Model Skill Reporting

# %% [markdown]
# ## Simulate ground truth data

# %%
data = loadCSV("sirs-simulated.csv")
times = data.time
infected_ground_truth = value(data.I)

# %% [markdown]
# ## Load and simulate models of interest

# %%
nSamples = 200
model1 = loadESL("sir.easel")
model2 = loadESL("sir-vd.easel")
model3 = loadESL("sirs.easel")

# %%
model1_samples = value(sample(model1.I at times, nSamples))
model2_samples = value(sample(model2.I at times, nSamples))
model3_samples = value(sample(model3.I at times, nSamples))

# %% [markdown]
# ## Compute ranking

# %%
alphas = [0.02, 0.05, 0.1, 0.2, 0.4, 0.8]
ranks = modelSkillRank([model1_samples, model2_samples, model3_samples], 
                        alphas, 
                        infected_ground_truth)

table(["model", "mean score"], [["model1", "model2", "model3"], ranks])
# Out:
# |model|mean score|
# |---|---|
# |model1|0.3|
# |model2|0.6|
# |model3|0.6|

# %% [markdown]
# ## Plot models vs. ground truth

# %%
m1 = series(mean(model1_samples), "Model 1", {{style="line"}})
m2 = series(mean(model2_samples), "Model 2", {{style="line"}})
m3 = series(mean(model3_samples), "Model 3", {{style="line"}})
ground_truth = series(infected_ground_truth, "Truth", {{style="squares"}})

# %%
plot("Models vs. Actual", 
     [m1, m2, m3, ground_truth],
     times,
     "T")

# %% [markdown]
# ## Distribution of Model Predictions

# %%
histogram(sample(model1.I at max(data.time) + 7, 100), 20)
histogram(sample(model2.I at max(data.time) + 7, 100), 20)
histogram(sample(model3.I at max(data.time) + 7, 100), 20)
# Out:
# [{"lo": 7.4, "hi": 8.25, "count": 9}, {"lo": 16.75, "hi": 17.6, "count": 2}, {"lo": 11.649999999999999, "hi": 12.5, "count": 13}, {"lo": 19.299999999999997, "hi": 20.15, "count": 2}, {"lo": 14.2, "hi": 15.049999999999999, "count": 7}, {"lo": 6.55, "hi": 7.4, "count": 1}, {"lo": 10.8, "hi": 11.649999999999999, "count": 10}, {"lo": 20.15, "hi": 21.0, "count": 2}, {"lo": 5.7, "hi": 6.55, "count": 4}, {"lo": 17.6, "hi": 18.45, "count": 2}, {"lo": 9.95, "hi": 10.8, "count": 6}, {"lo": 4.85, "hi": 5.7, "count": 5}, {"lo": 12.5, "hi": 13.35, "count": 9}, {"lo": 18.45, "hi": 19.299999999999997, "count": 4}, {"lo": 13.35, "hi": 14.2, "count": 10}, {"lo": 4.0, "hi": 4.85, "count": 1}, {"lo": 15.9, "hi": 16.75, "count": 5}, {"lo": 8.25, "hi": 9.1, "count": 8}]
# [{"lo": 18.6, "hi": 20.25, "count": 4}, {"lo": 36.75, "hi": 38.4, "count": 5}, {"lo": 26.85, "hi": 28.5, "count": 15}, {"lo": 41.7, "hi": 43.349999999999994, "count": 2}, {"lo": 31.799999999999997, "hi": 33.45, "count": 8}, {"lo": 16.95, "hi": 18.6, "count": 1}, {"lo": 25.2, "hi": 26.85, "count": 2}, {"lo": 43.349999999999994, "hi": 45.0, "count": 4}, {"lo": 33.45, "hi": 35.099999999999994, "count": 9}, {"lo": 38.4, "hi": 40.05, "count": 11}, {"lo": 23.549999999999997, "hi": 25.2, "count": 5}, {"lo": 28.5, "hi": 30.15, "count": 10}, {"lo": 21.9, "hi": 23.549999999999997, "count": 5}, {"lo": 40.05, "hi": 41.7, "count": 2}, {"lo": 30.15, "hi": 31.799999999999997, "count": 8}, {"lo": 12.0, "hi": 13.65, "count": 2}, {"lo": 35.099999999999994, "hi": 36.75, "count": 4}, {"lo": 20.25, "hi": 21.9, "count": 3}]
# [{"lo": 224.25, "hi": 239.2, "count": 7}, {"lo": 269.09999999999997, "hi": 284.05, "count": 32}, {"lo": 284.05, "hi": 299.0, "count": 9}, {"lo": 239.2, "hi": 254.14999999999998, "count": 15}, {"lo": 254.14999999999998, "hi": 269.09999999999997, "count": 36}, {"lo": 0.0, "hi": 14.95, "count": 1}]

# %%
event = sample(model3.I > 260 at [0 .. 200 by 1], 100)
max(P(event))
# Out:
# [[{"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}] @ 0, [{"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": false, "type": "bool"}, {"value": fals ...
