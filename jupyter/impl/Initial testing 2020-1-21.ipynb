# %%
sirmodel = loadESL("sir.askee")

# %%
sirdata = simulate(sirmodel, 0.0, 120.0, 1.0)

# %%
plot(sirdata, "time")
# Out:
# Plot could not be displayed

# %%
save("../cpp/sir.cpp", generateSimulator(sirmodel))

# %%
plot(loadCSV("../cpp/sir-runner1.csv"), "time")
# Out:
# Plot could not be displayed

# %%
plot(loadCSV("../cpp/sir-runner2.csv"), "time")
# Out:
# Plot could not be displayed
